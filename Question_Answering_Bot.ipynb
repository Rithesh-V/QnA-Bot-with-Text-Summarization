# %% [markdown]
# <a href="https://colab.research.google.com/github/Rithesh-V/QnA-Bot-with-Text-Summarization/blob/main/Question_Answering_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install nltk

# %%
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import re
from transformers import pipeline
import nltk
from transformers import pipeline
nltk.download('words')
nltk.download('punkt')
nltk.download('stopwords')
#import time

def scrape_wikipedia_pages(topic):
    url = f"https://en.wikipedia.org/wiki/{topic}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    content_div = soup.find("div", {"id": "bodyContent"})
    line=''
    line += " ".join([p.text for p in content_div.find_all("p")])
    return line

def preprocess_text(text):
    text = re.sub(r'[^\w\s]', '', text)

    text = text.lower()

    words = word_tokenize(text)

    english_vocab = set(word.lower() for word in nltk.corpus.words.words())
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]


    text = ' '.join(words)
    return text


def divide_documents(text):

    paragraphs = text.split('\n\n')

    sentences = []
    for paragraph in paragraphs:
        sentences.extend(sent_tokenize(paragraph))
    return sentences


def generate_summaries(sentences):

    summaries = []
    for sentence in sentences:

        summary = sentence
        summaries.append(summary)
    return summaries
qa_pipeline = pipeline("question-answering", model="distilbert-base-cased-distilled-squad", tokenizer="distilbert-base-cased-distilled-squad")
'''model_checkpoint = "huggingface-course/bert-finetuned-squad"
qa_pipeline = pipeline("question-answering", model=model_checkpoint)'''
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# 'model_checkpoint = "huggingface-course/bert-finetuned-squad"\nqa_pipeline = pipeline("question-answering", model=model_checkpoint)'

# %%
number = int(input("Enter the number of topics: "))
for i in range(number):
    topic=''
    text=''
    topic = input("Enter the topic: ")
    text = scrape_wikipedia_pages(topic)
text = preprocess_text(text)
sentences = divide_documents(text)
summaries = generate_summaries(sentences)
#print(summaries)
question = input("Enter the question: ")
answers= qa_pipeline(question=question, context=summaries[0])
print(question)
print("Answer: " ,answers['answer'])
# Out:
# Enter the number of topics: 1
# Enter the topic: batman
# Enter the question: who is batman?
# who is batman?
# Answer:  julius schwartz

# %%
from transformers import pipeline

# Replace this with your own checkpoint
model_checkpoint = "huggingface-course/bert-finetuned-squad"
question_answerer = pipeline("question-answering", model=model_checkpoint)

context = summaries[0]
question = "how many times did lewis win?"
question_answerer(question=question, context=context)
# Out:
# {'score': 1.6091646102722734e-05, 'start': 50174, 'end': 50176, 'answer': '28'}
